# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
topk = [10, 20, 30, 50, 75, 100, 125, 150, 175, 196]
sr_rate = [81.6, 75.0, 71.6, 57.0, 61.2, 88.9, 79.2, 60.0, 70.0, 55.0]

plt.plot(topk, sr_rate)
plt.xlabel('Top-k')
plt.ylabel('Success Rate')
plt.title('Success Rate vs Top-k')
plt.show()
