# %%
import torch

# %%
data = torch.load("/home/nitesh/IsaacSim5/IsaacLab/adapter.siglip2.z256_best.pt", weights_only=False)

# %%
data.keys()
# Out:
# dict_keys(['epoch', 'global_step', 'a_vlm_state_dict', 'action_head_state_dict', 'avg_loss', 'avg_action_mse', 'avg_align_acc', 'avg_action_acc', 'best_action_mse', 'config'])

# %%
data['avg_align_acc']
# Out:
# 0.4853291531740609

# %%
data["avg_action_acc"]
# Out:
# 0.9673608824358149

# %%
print(f"Avg action acc: {data['avg_action_acc']}")
print(f"Avg align acc: {data['avg_align_acc']}")
# Out:
# Avg action acc: 0.9673608824358149
# Avg align acc: 0.4853291531740609
