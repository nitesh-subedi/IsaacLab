# %%
import torch

# %%
data = torch.load("/home/nitesh/IsaacSim5/IsaacLab/nav_runs/rollout_30k/step-00000000.pt", weights_only=False)

# %%
data.keys()
# Out:
# dict_keys(['obs', 'actions', 'rewards', 'dones', 'info'])

# %%
data['info']["rgb"].shape
# Out:
# torch.Size([384, 384, 3])
